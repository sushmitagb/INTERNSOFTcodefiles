# %% [markdown]
# SESSION2-STRINGS AND LIST OBJECTS

# %% [markdown]
# creating a string

# %%
#single word
'myra'
# Out:
# 'myra'

# %%
#entire phrase
'going for ice cream is a real treat'
# Out:
# 'going for ice cream is a real treat'

# %%
#we can also use double quotes
"taking my dog for a walk is fun"
# Out:
# 'taking my dog for a walk is fun'

# %%
#be careful with quotes
"I'm so hungry"
# Out:
# "I'm so hungry"

# %% [markdown]
# printing a string

# %%
#we can simply declare a string
'Always be prepared'
# Out:
# 'Always be prepared'

# %%
#note that we can't output multiple strings this way
'always be prepared 1'
'always be prepared 2'
# Out:
# 'always be prepared 2'

# %%
print('keep smiling1')
print('keep smiling2')
print('use\n try and try until you get a sucess')
print('see what i mean?')
# Out:
# keep smiling1
# keep smiling2
# use
#  try and try until you get a sucess
# see what i mean?

# %% [markdown]
# string basics

# %%
len('The only joy in the world is to begin')
# Out:
# 37

# %% [markdown]
# string indexing

# %%
#assign g as a string
g='keep smiling'

# %%
#check
g
# Out:
# 'keep smiling'

# %%
#print the object
print(g)
# Out:
# keep smiling

# %% [markdown]
# lets start indexing

# %%
#show first element (in this case a letter)
g[5]
# Out:
# 's'

# %%
g[3]
# Out:
# 'p'

# %%
g[6]
# Out:
# 'm'

# %%
#grab everything past the first term all the way to the length of g which is len(g)
g[3:]
# Out:
# 'p smiling'

# %%
#note that there is no change to the original g
g
# Out:
# 'keep smiling'

# %%
#grab everything up to the 3rd index
g[:5]
# Out:
# 'keep '

# %%
#Everything
g[:]
# Out:
# 'keep smiling'

# %%
#Last letter 
g[-6]
# Out:
# 'm'

# %%
#Grab everything but the last letter
g[:-1]
# Out:
# 'keep smilin'

# %%
g[::2]
# Out:
# 'ke mln'

# %%
g[::3]
# Out:
# 'kpmi'

# %%
g[::-4]
# Out:
# 'gip'

# %% [markdown]
# string properties

# %%
g
# Out:
# 'keep smiling'

# %%
g[:0]
# Out:
# ''

# %%
g
# Out:
# 'keep smiling'

# %%
g+'Always be happy!'
# Out:
# 'keep smilingAlways be happy!'

# %%
g=g+'Always be happy!'

# %%
print(g)
# Out:
# keep smilingAlways be happy!

# %%
g
# Out:
# 'keep smilingAlways be happy!'

# %%
letter='a'

# %%
letter*23
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaa'

# %% [markdown]
# BASIC BUILT-IN STRING METHODS

# %%
g
# Out:
# 'keep smilingAlways be happy!'

# %%
g.upper()
# Out:
# 'KEEP SMILINGALWAYS BE HAPPY!'

# %%
g.lower()
# Out:
# 'keep smilingalways be happy!'

# %%
g.split()
# Out:
# ['keep', 'smilingAlways', 'be', 'happy!']

# %%
g.split('1')
# Out:
# ['keep smilingAlways be happy!']

# %% [markdown]
# PRINT FORMATING

# %%
'Insert another string with curly brackets:{}'.format({'The inserted string'})
# Out:
# "Insert another string with curly brackets:{'The inserted string'}"

# %%
print(g)
g.count('2')
# Out:
# keep smilingAlways be happy!
# 0

# %%
g.find('5')
# Out:
# -1

# %%
g.center(10,'a')
# Out:
# 'keep smilingAlways be happy!'

# %%
'anu\ttanu'.expandtabs()
# Out:
# 'anu     tanu'

# %%
g='anu'

# %%
g.isalnum()
# Out:
# True

# %%
g.isalpha()
# Out:
# True

# %%
g.islower()
# Out:
# True

# %%
g.isspace()
# Out:
# False

# %%
g.istitle()
# Out:
# False

# %%
g.isupper()
# Out:
# False

# %%
g.endswith("o")
# Out:
# False

# %% [markdown]
# BUILT-IN REG.EXPRESSIONS

# %%
g.split('s')
# Out:
# ['anu']

# %%
g.partition('f')
# Out:
# ('anu', '', '')

# %%
g
# Out:
# 'anu'

# %% [markdown]
# LISTS

# %%
my_list=[2,4,6]

# %%
my_list=['A life is like a thread',23,100,232,'o'] 
my_list
# Out:
# ['A life is like a thread', 23, 100, 232, 'o']

# %%
len(my_list)
# Out:
# 5

# %% [markdown]
# INDEXING AND SLICING

# %%
my_list=['three','one','6',4,5]

# %%
my_list[1]
# Out:
# 'one'

# %%
my_list[2:]
# Out:
# ['6', 4, 5]

# %%
my_list[:5]
# Out:
# ['three', 'one', '6', 4, 5]

# %%
my_list+['she was at the park']
# Out:
# ['three', 'one', '6', 4, 5, 'she was at the park']

# %%
my_list
# Out:
# ['three', 'one', '6', 4, 5]

# %%
my_list=my_list+['she was at the park all day']

# %%
my_list
# Out:
# ['three', 'one', '6', 4, 5, 'she was at the park all day']

# %%
my_list*3
# Out:
# ['three',
#  'one',
#  '6',
#  4,
#  5,
#  'she was at the park all day',
#  'three',
#  'one',
#  '6',
#  4,
#  5,
#  'she was at the park all day',
#  'three',
#  'one',
#  '6',
#  4,
#  5,
#  'she was at the park all day']

# %%
my_list
# Out:
# ['three', 'one', '6', 4, 5, 'she was at the park all day']

# %% [markdown]
# BASIC LIST METHODS

# %%
l=[4,5,6]

# %%
l.append('new car!')

# %%
l
# Out:
# [4, 5, 6, 'new car!']

# %%
l.pop(0)
# Out:
# 4

# %%
l
# Out:
# [5, 6, 'new car!']

# %%
popped_item=l.pop()

# %%
popped_item
# Out:
# 'new car!'

# %%
l
# Out:
# [5, 6]

# %%
new_list=['a','e','i','o','u']

# %%
new_list
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
new_list.reverse()

# %%
new_list
# Out:
# ['u', 'o', 'i', 'e', 'a']

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %% [markdown]
# NESTING LISTS

# %%
lst_1=[3,2,1]
lst_2=[6,5,4]
lst_3=[9,8,7]

matrix = [lst_1,lst_2,lst_3]

# %%
matrix
# Out:
# [[3, 2, 1], [6, 5, 4], [9, 8, 7]]

# %%
matrix[1]
# Out:
# [6, 5, 4]

# %%
matrix[1][0]
# Out:
# 6

# %% [markdown]
# LIST COMPREHENSIONS

# %%
first_col=[row[0] for row in matrix]

# %%
first_col
# Out:
# [3, 6, 9]

# %% [markdown]
# ADVANCED LISTS

# %%
l=[5,6,7]

# %% [markdown]
# APPEND

# %%
l.append(3)
l
# Out:
# [5, 6, 7, 3]

# %% [markdown]
# count

# %%
l.count(10)
# Out:
# 0

# %%
l.count(1)
# Out:
# 0

# %% [markdown]
# EXTEND

# %%
x=[6,2,3]
x.append([1,5])
print(x)
# Out:
# [6, 2, 3, [1, 5]]

# %%
x=[6,2,3]
x.extend([1,5])
print(x)
# Out:
# [6, 2, 3, 1, 5]

# %% [markdown]
# INDEX

# %%
print(l)
l.index(5)
# Out:
# [5, 6, 7, 3]
# 0

# %%
l.index(6)
# Out:
# 1

# %% [markdown]
# INSERT

# %%
l
# Out:
# [5, 6, 7, 3]

# %%
l.insert(2,'inserted')

# %%
l
# Out:
# [5, 6, 'inserted', 7, 3]

# %% [markdown]
# POP

# %%
ele=l.pop()

# %%
l
# Out:
# [5, 6, 'inserted', 7]

# %%
ele
# Out:
# 3

# %% [markdown]
# REMOVE

# %%
l
# Out:
# [5, 6, 'inserted', 7]

# %%
l.remove("inserted")

# %%
l
# Out:
# [5, 6, 7]

# %%
l.remove(5)

# %%
l
# Out:
# [6, 7]

# %% [markdown]
# REVERSE

# %%
l.reverse()

# %%
l
# Out:
# [7, 6]

# %% [markdown]
# SORT

# %%
l
# Out:
# [7, 6]

# %%
l.sort()

# %%
l
# Out:
# [6, 7]
