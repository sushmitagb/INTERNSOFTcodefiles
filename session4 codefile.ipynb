# %% [markdown]
# SESSION4 OBJECT ORIENTED PROGRAMMING AND FILE I/O

# %%
class Person:
    pass

alexa_doe = Person()
alexa_doe.name = "Anu"
alexa_doe.surname = "reddy"
alexa_doe.year_of_birth = 2000


print(alexa_doe)
print("%s %s was born in %d." %
      (alexa_doe.name, alexa_doe.surname, alexa_doe.year_of_birth))
# Out:
# ...
# Anu reddy was born in 2000.

# %%
class Person:
    def __init__(self, name, surname, year_of_birth):
        self.name = name
        self.surname = surname
        self.year_of_birth = year_of_birth

# %%
anu = Person("Anu", "reddy", 2000)
print(anu)
print("%s %s was born in %d"% (anu.name,anu.surname,anu.year_of_birth))
# Out:
# ...
# Anu reddy was born in 2000

# %% [markdown]
# METHODS

# %%
class Person:
    def __init__(self, name, surname, year_of_birth):
        self.name = name
        self.surname = surname
        self.year_of_birth = year_of_birth
    
    def age(self, current_year):
        return current_year - self.year_of_birth
    
    def __str__(self):
        return "%s %s was born in %d ." % (self.name, self.surname, self.year_of_birth)
    
anu = Person("Anu", "reddy", 2000)
print(anu)
print(anu.age(2020))
# Out:
# Anu reddy was born in 2000 .
# 20

# %% [markdown]
# INHERITANCE

# %%
class Student(Person):
    def __init__(self, student_id, *args, **kwargs):
        super(Student, self).__init__(*args, **kwargs)
        self._student_id = student_id
        
kaira = Student(1, 'kaira', 'topa', 2005)
print(kaira)
print(type(kaira))
print(isinstance(kaira, Person))
print(isinstance(kaira, object))
# Out:
# kaira topa was born in 2005 .
# <class '__main__.Student'>
# True
# True

# %% [markdown]
# OVERRIDING METHODS

# %%
class Student(Person):
    def __init__(self, student_id, *args, **kwargs):
        super(Student, self).__init__(*args, **kwargs)
        self._student_id = student_id
        
    def __str__(self):
        return super(Student, self).__str__() + " And has ID: %d" % self._student_id
        
kaira = Student(1, 'kaira', 'topa', 2005)
print(kaira)
# Out:
# kaira topa was born in 2005 . And has ID: 1

# %% [markdown]
# POLYMORPHISM AND DUCK TYPING

# %%
def summer(s, r):
    return s+ r

print(summer(2, 3))
print(summer(["g", "h", "i"], ["j", "k"]))
print(summer("sgbrm", "kvpstr"))
# Out:
# 5
# ['g', 'h', 'i', 'j', 'k']
# sgbrmkvpstr

# %% [markdown]
# FILES

# %%
# %%writefile naira.txt
# The kite can go up in the sky if it is windy
# Out:
# Overwriting naira.txt

# %%
my_file = open('naira.txt')

# %%
my_file.read()
# Out:
# 'The kite can go up in the sky if it is windy\n'

# %%
my_file.read()
# Out:
# ''

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.read()
# Out:
# 'The kite can go up in the sky if it is windy\n'

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.readlines()
# Out:
# ['The kite can go up in the sky if it is windy\n']

# %%
my_file = open('naira.txt','w+')

# %%
my_file.write("I can go to the park to play")
# Out:
# 28

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.read()
# Out:
# 'I can go to the park to play'

# %% [markdown]
# ITERATING THROUGH A FILE

# %%
# %%writefile rash.txt
# first line
# second line
# Out:
# Overwriting rash.txt

# %%
for line in open("rash.txt"):
    print(line)
# Out:
# first line
#
# second line

# %%
for card in open('rash.txt'):
    print(card)
# Out:
# first line
#
# second line

# %% [markdown]
# STRINGIO

# %%
from io import StringIO

# %%
message="We played two games back to back."

# %%
# Use StringIO method to set as file object
f = StringIO(message)

# %%
f.read()
# Out:
# 'We played two games back to back.'

# %%
f.write(' she was at the park all day')
# Out:
# 28

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'We played two games back to back. she was at the park all day'
